# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
attn_weight = np.load('../models/residuals_attn/attn_weights.npy')

# %%
plt.imshow(attn_weight*1500)
plt.axvline(1024, c='r', linewidth=2)
plt.axhline(1024, c='r', linewidth=2)
plt.colorbar()
plt.clim(0,1)
plt.show()
